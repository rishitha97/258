# %%
from torchvision.datasets import MNIST
from torchvision import transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
class Numpy(object):

  def __init__(self, data, requires_grad=False):
      self.data = data
      if not isinstance(data, np.ndarray):
          self.data = np.array(data)
      self.requires_grad = requires_grad
      self._grad = None
      self._grad_fn = None


  def grad_fn(self):
      return self._grad_fn

  def grad(self):
      return self._grad

  def backward(self, grad=None):

      if grad is None and self._grad is None:
          grad = self.__class__(1., requires_grad=False)

      elif self.grad is not None:
          grad = self._grad

      self.grad_fn.backward(grad)
      return True

  def __repr__(self):
      return str(self.data.__repr__())

  def add_grad(self, grad):
      if self._grad is None:
          self._grad = grad
      else:
          self._grad += grad

# %%
class Layer:

  def __call__(self, *args):
      return self.forward(*args)

class Relu(Layer):

  def forward(self,x):
      self.x = x
      return np.maximum(np.zeros_like(x), x)
    
  def backward(self, grad):
      grad_input = (self.x > 0) * grad
      return grad_input

class MSE(Layer):

  def forward(self, x, y):
      self.x = x
      self.y = np.expand_dims(y, axis=-1)
      #print(self.x.shape[0]*2)
      return ((x - self.y)**2) / (self.x.shape[0]*2)

  def backward(self, grad=None):
      return (self.x - self.y) / self.x.shape[0]

# %%
class Linear(Layer):

  def __init__(self, input, output, lr=0.0002):
    super().__init__()
    self.weight = 2*np.random.random((input, output)) - 1
    self.bias = 2*np.random.random((output)) - 1
    self.lr = lr

  def forward(self, x):
    self.x = x
    return np.dot(x,self.weight) + self.bias

  def backward(self, grad):
    bias_grad = grad.mean(axis=0)*self.x.shape[0]
    weight_grad = np.dot(self.x.T, grad)
    grad_input = np.dot(grad, self.weight.T)
    
    self.weight -= weight_grad * self.lr
    self.bias -= bias_grad * self.lr

    return grad_input

# %%
lr=0.00001
class Model(Layer):
  def __init__(self, lr=0.00001):
      self.lr = lr
      self.layers = [
          Linear(784,400, lr=self.lr),
          Relu(),
          Linear(400,100, lr=self.lr),
          Relu(),
          Linear(100,10, lr=self.lr)        
      ]

  def forward(self,x):
      for l in self.layers:
          x = l(x)
      return x

  def backward(self, grad):
      for l in self.layers[::-1]:
          grad = l.backward(grad)

      return grad

# %%
simple = transforms.Compose([
    transforms.ToTensor(),
])
ds = MNIST('./mnist', download=True, transform=simple)
ld = DataLoader(ds, batch_size=2, pin_memory=True, drop_last=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting ./mnist/MNIST/raw/train-images-idx3-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting ./mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting ./mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ./mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting ./mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST/raw
#
# Processing...
# Done!
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:502: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:143.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
mm = Model()
loss = MSE()
_loss_avg = 0 
for epochs in range(5):
    cnt = 0
    total = 0
    for i, (img, label) in enumerate(ld):
        x = img.view(2,-1).numpy()
        res = mm(x)
        _loss = loss(res, label.numpy())
        total += label.data.size(0)
        cnt += int(np.argmax(res) == np.argmax(label.numpy()))
        _loss_avg += _loss.mean() 
        grad = loss.backward(1)
        mm.backward(grad)
        if i % 1000 == 0:
          print('Train - Epoch %d, Batch: %d, Loss: %f' % (epochs, i, _loss_avg/1000))
          _loss_avg = 0
        loss.backward()
        mm.backward(grad)
    print(' Accuracy: %f' % (float(cnt) / len(ds)))
# Out:
# Train - Epoch 0, Batch: 0, Loss: 9.140558
# Train - Epoch 0, Batch: 1000, Loss: 79.931840
# Train - Epoch 0, Batch: 2000, Loss: 3.839712
# Train - Epoch 0, Batch: 3000, Loss: 2.839282
# Train - Epoch 0, Batch: 4000, Loss: 2.540469
# Train - Epoch 0, Batch: 5000, Loss: 2.425599
# Train - Epoch 0, Batch: 6000, Loss: 1.827842
# Train - Epoch 0, Batch: 7000, Loss: 1.982463
# Train - Epoch 0, Batch: 8000, Loss: 2.171599
# Train - Epoch 0, Batch: 9000, Loss: 1.778993
# Train - Epoch 0, Batch: 10000, Loss: 1.671248
# Train - Epoch 0, Batch: 11000, Loss: 1.622605
# Train - Epoch 0, Batch: 12000, Loss: 1.682661
# Train - Epoch 0, Batch: 13000, Loss: 1.503634
# Train - Epoch 0, Batch: 14000, Loss: 1.569863
# Train - Epoch 0, Batch: 15000, Loss: 1.479401
# Train - Epoch 0, Batch: 16000, Loss: 1.587463
# Train - Epoch 0, Batch: 17000, Loss: 1.429244
# Train - Epoch 0, Batch: 18000, Loss: 1.346901
# Train - Epoch 0, Batch: 19000, Loss: 1.471290
# Train - Epoch 0, Batch: 20000, Loss: 1.370047
# Train - Epoch 0, Batch: 21000, Loss: 1.365826
# Train - Epoch 0, Batch: 22000, Loss: 1.389292
# Train - Epoch 0, Batch: 23000, Loss: 1.446271
# Train - Epoch 0, Batch: 24000, Loss: 1.370399
# Train - Epoch 0, Batch: 25000, Loss: 1.326474
# Train - Epoch 0, Batch: 26000, Loss: 1.305582
# Train - Epoch 0, Batch: 27000, Loss: 1.238704
# Train - Epoch 0, Batch: 28000, Loss: 1.139467
# Train - Epoch 0, Batch: 29000, Loss: 1.214793
#  Accuracy: 0.033800
# Train - Epoch 1, Batch: 0, Loss: 1.050470
# Train - Epoch 1, Batch: 1000, Loss: 1.188048
# Train - Epoch 1, Batch: 2000, Loss: 1.149688
# Train - Epoch 1, Batch: 3000, Loss: 1.105143
# Train - Epoch 1, Batch: 4000, Loss: 1.178647
# Train - Epoch 1, Batch: 5000, Loss: 1.229300
# Train - Epoch 1, Batch: 6000, Loss: 1.162924
# Train - Epoch 1, Batch: 7000, Loss: 1.178927
# Train - Epoch 1, Batch: 8000, Loss: 1.316738
# Train - Epoch 1, Batch: 9000, Loss: 1.206649
# Train - Epoch 1, Batch: 10000, Loss: 1.085758
# Train - Epoch 1, Batch: 11000, Loss: 1.119376
# Train - Epoch 1, Batch: 12000, Loss: 1.184339
# Train - Epoch 1, Batch: 13000, Loss: 1.073592
# Train - Epoch 1, Batch: 14000, Loss: 1.140717
# Train - Epoch 1, Batch: 15000, Loss: 1.114310
# Train - Epoch 1, Batch: 16000, Loss: 1.168882
# Train - Epoch 1, Batch: 17000, Loss: 1.086477
# Train - Epoch 1, Batch: 18000, Loss: 1.015343
# Train - Epoch 1, Batch: 19000, Loss: 1.123378
# Train - Epoch 1, Batch: 20000, Loss: 1.061617
# Train - Epoch 1, Batch: 21000, Loss: 1.083608
# Train - Epoch 1, Batch: 22000, Loss: 1.103674
# Train - Epoch 1, Batch: 23000, Loss: 1.145936
# Train - Epoch 1, Batch: 24000, Loss: 1.087064
# Train - Epoch 1, Batch: 25000, Loss: 1.069036
# Train - Epoch 1, Batch: 26000, Loss: 1.053045
# Train - Epoch 1, Batch: 27000, Loss: 1.026477
# Train - Epoch 1, Batch: 28000, Loss: 0.930888
# Train - Epoch 1, Batch: 29000, Loss: 0.986642
#  Accuracy: 0.026367
# Train - Epoch 2, Batch: 0, Loss: 0.856619
# Train - Epoch 2, Batch: 1000, Loss: 0.952354
# Train - Epoch 2, Batch: 2000, Loss: 0.959055
# Train - Epoch 2, Batch: 3000, Loss: 0.942619
# Train - Epoch 2, Batch: 4000, Loss: 0.999416
# Train - Epoch 2, Batch: 5000, Loss: 1.040571
# Train - Epoch 2, Batch: 6000, Loss: 0.997940
# Train - Epoch 2, Batch: 7000, Loss: 1.016749
# Train - Epoch 2, Batch: 8000, Loss: 1.118741
# Train - Epoch 2, Batch: 9000, Loss: 1.024961
# Train - Epoch 2, Batch: 10000, Loss: 0.915457
# Train - Epoch 2, Batch: 11000, Loss: 0.955455
# Train - Epoch 2, Batch: 12000, Loss: 1.012708
# Train - Epoch 2, Batch: 13000, Loss: 0.922161
# Train - Epoch 2, Batch: 14000, Loss: 0.982284
# Train - Epoch 2, Batch: 15000, Loss: 0.959794
# Train - Epoch 2, Batch: 16000, Loss: 1.008225
# Train - Epoch 2, Batch: 17000, Loss: 0.943339
# Train - Epoch 2, Batch: 18000, Loss: 0.874185
# Train - Epoch 2, Batch: 19000, Loss: 0.970178
# Train - Epoch 2, Batch: 20000, Loss: 0.912638
# Train - Epoch 2, Batch: 21000, Loss: 0.944256
# Train - Epoch 2, Batch: 22000, Loss: 0.962517
# Train - Epoch 2, Batch: 23000, Loss: 1.002975
# Train - Epoch 2, Batch: 24000, Loss: 0.951585
# Train - Epoch 2, Batch: 25000, Loss: 0.931358
# Train - Epoch 2, Batch: 26000, Loss: 0.912183
# Train - Epoch 2, Batch: 27000, Loss: 0.910757
# Train - Epoch 2, Batch: 28000, Loss: 0.815583
# Train - Epoch 2, Batch: 29000, Loss: 0.864439
#  Accuracy: 0.022667
# Train - Epoch 3, Batch: 0, Loss: 0.743743
# Train - Epoch 3, Batch: 1000, Loss: 0.830934
# Train - Epoch 3, Batch: 2000, Loss: 0.846091
# Train - Epoch 3, Batch: 3000, Loss: 0.843640
# Train - Epoch 3, Batch: 4000, Loss: 0.891247
# Train - Epoch 3, Batch: 5000, Loss: 0.923142
# Train - Epoch 3, Batch: 6000, Loss: 0.889392
# Train - Epoch 3, Batch: 7000, Loss: 0.916224
# Train - Epoch 3, Batch: 8000, Loss: 1.000093
# Train - Epoch 3, Batch: 9000, Loss: 0.911623
# Train - Epoch 3, Batch: 10000, Loss: 0.809406
# Train - Epoch 3, Batch: 11000, Loss: 0.851917
# Train - Epoch 3, Batch: 12000, Loss: 0.896513
# Train - Epoch 3, Batch: 13000, Loss: 0.826739
# Train - Epoch 3, Batch: 14000, Loss: 0.879713
# Train - Epoch 3, Batch: 15000, Loss: 0.853579
# Train - Epoch 3, Batch: 16000, Loss: 0.907631
# Train - Epoch 3, Batch: 17000, Loss: 0.843590
# Train - Epoch 3, Batch: 18000, Loss: 0.782182
# Train - Epoch 3, Batch: 19000, Loss: 0.868129
# Train - Epoch 3, Batch: 20000, Loss: 0.812796
# Train - Epoch 3, Batch: 21000, Loss: 0.849959
# Train - Epoch 3, Batch: 22000, Loss: 0.863171
# Train - Epoch 3, Batch: 23000, Loss: 0.902309
# Train - Epoch 3, Batch: 24000, Loss: 0.859899
# Train - Epoch 3, Batch: 25000, Loss: 0.832134
# Train - Epoch 3, Batch: 26000, Loss: 0.817037
# Train - Epoch 3, Batch: 27000, Loss: 0.824753
# Train - Epoch 3, Batch: 28000, Loss: 0.736881
# Train - Epoch 3, Batch: 29000, Loss: 0.783339
#  Accuracy: 0.021100
# Train - Epoch 4, Batch: 0, Loss: 0.673609
# Train - Epoch 4, Batch: 1000, Loss: 0.750551
# Train - Epoch 4, Batch: 2000, Loss: 0.764925
# Train - Epoch 4, Batch: 3000, Loss: 0.768362
# Train - Epoch 4, Batch: 4000, Loss: 0.814424
# Train - Epoch 4, Batch: 5000, Loss: 0.842010
# Train - Epoch 4, Batch: 6000, Loss: 0.810453
# Train - Epoch 4, Batch: 7000, Loss: 0.838268
# Train - Epoch 4, Batch: 8000, Loss: 0.914143
# Train - Epoch 4, Batch: 9000, Loss: 0.830777
# Train - Epoch 4, Batch: 10000, Loss: 0.736151
# Train - Epoch 4, Batch: 11000, Loss: 0.776780
# Train - Epoch 4, Batch: 12000, Loss: 0.814546
# Train - Epoch 4, Batch: 13000, Loss: 0.757953
# Train - Epoch 4, Batch: 14000, Loss: 0.807796
# Train - Epoch 4, Batch: 15000, Loss: 0.779313
# Train - Epoch 4, Batch: 16000, Loss: 0.837511
# Train - Epoch 4, Batch: 17000, Loss: 0.772522
# Train - Epoch 4, Batch: 18000, Loss: 0.716064
# Train - Epoch 4, Batch: 19000, Loss: 0.796467
# Train - Epoch 4, Batch: 20000, Loss: 0.740766
# Train - Epoch 4, Batch: 21000, Loss: 0.781258
# Train - Epoch 4, Batch: 22000, Loss: 0.790011
# Train - Epoch 4, Batch: 23000, Loss: 0.826780
# Train - Epoch 4, Batch: 24000, Loss: 0.793450
# Train - Epoch 4, Batch: 25000, Loss: 0.758793
# Train - Epoch 4, Batch: 26000, Loss: 0.749728
# Train - Epoch 4, Batch: 27000, Loss: 0.761181
# Train - Epoch 4, Batch: 28000, Loss: 0.679718
# Train - Epoch 4, Batch: 29000, Loss: 0.722983
#  Accuracy: 0.019583
